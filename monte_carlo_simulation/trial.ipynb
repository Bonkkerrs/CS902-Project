# %%
import seaborn as sns

# %%
import monte_carlo

# %%
stockList = ['BABA.US','NIO.US','TWTR.US','GDX.US','700.HK','3799.HK']
mc_sims = 100
T = 100
initial_portfolio = 10000
days_back = 300
m = monte_carlo.MonteCarloEstimator(stockList, mc_sims, T, initial_portfolio, days_back)

# %%
m.covMatrix
# Out:
# Symbols   BABA.US    NIO.US   TWTR.US    GDX.US    700.HK   3799.HK
# Symbols
# BABA.US  0.001831  0.001450  0.000516  0.000080  0.000805  0.000112
# NIO.US   0.001450  0.002308  0.000689  0.000062  0.000607  0.000073
# TWTR.US  0.000516  0.000689  0.001056  0.000008  0.000136 -0.000083
# GDX.US   0.000080  0.000062  0.000008  0.000340  0.000052  0.000055
# 700.HK   0.000805  0.000607  0.000136  0.000052  0.001067  0.000179
# 3799.HK  0.000112  0.000073 -0.000083  0.000055  0.000179  0.000411

# %%
m.returns
# Out:
# Symbols      BABA.US    NIO.US   TWTR.US    GDX.US    700.HK   3799.HK
# Date
# 2021-07-09       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-07-12 -0.002234  0.017790  0.012904 -0.013971 -0.007428 -0.010832
# 2021-07-13  0.019613 -0.029780 -0.003722  0.011497  0.039289 -0.008760
# 2021-07-14  0.009498 -0.042482  0.009626  0.013444  0.001800  0.002209
# 2021-07-15  0.015414  0.014634 -0.031308  0.006618  0.015274 -0.019818
# ...              ...       ...       ...       ...       ...       ...
# 2022-04-28  0.029325  0.010143  0.009663  0.020461  0.014934  0.025575
# 2022-04-29  0.067979 -0.013585 -0.001833 -0.011861  0.110653  0.002494
# 2022-05-02  0.042435  0.047904  0.002448 -0.012575  0.000000  0.000000
# 2022-05-03 -0.008201  0.001714 -0.005495  0.016208  0.006889  0.009950
# 2022-05-04  0.010261  0.034227  0.003888  0.019083 -0.030526  0.000000
#
# [213 rows x 6 columns]

# %%
m.
# Out:
# <AxesSubplot:xlabel='Symbols', ylabel='Symbols'>
